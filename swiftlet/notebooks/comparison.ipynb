# %% [markdown]
# # Performance comparison between Swiftlet and Lark parsing library

# %% [markdown]
# Import required library

# %%
import random as rnd

import pandas as pd
import seaborn as sns
import timeit
import cProfile


import swiftlet
import lark

# %% [markdown]
# Text expression generator

# %%
def gen_text_expr(n):
    expr = "{}".format(rnd.randint(1, n))
    opt = ["+", "-", "*", "/"]

    for _ in range(n):
        expr += " {} {}".format(rnd.choice(opt), str(rnd.randint(1, n)))
    return expr.strip()

texts = [gen_text_expr(10 * i) for i in range(1, 500)]

# %% [markdown]
# ## Swiftlet Parser function

# %%
def parser_swiftlet(text: str):
    _grammar = """
    start: expr
    expr: expr "+" factors -> add
        | expr "-" factors -> sub
        | factors

    factors: factors "*" INT -> mul
        | factors "/" INT -> div
        | INT

    # %import (WS, INT)
    # %ignore WS
    """
    parser = swiftlet.Swiftlet(grammar=_grammar, algorithm="clr")
    ast = parser.parse(text)
    return ast

# %% [markdown]
# ## Lark Parser function

# %%
def parser_lark(text: str):
    _grammar = """
    start: expr
    expr: expr "+" factors -> add
        | expr "-" factors -> sub
        | factors

    factors: factors "*" INT -> mul
        | factors "/" INT -> div
        | INT

    # %import common.WS
    # %import common.INT
    # %ignore WS
    """
    _lark_parser = lark.Lark(_grammar, parser="lalr", keep_all_tokens=True)
    lark_ast = _lark_parser.parse(text=text)
    return lark_ast

# %%
number = 1000

# %%
array = []
for txt in texts[::100]:
    swiftlet_time = 1000 * timeit.timeit(lambda: parser_swiftlet(txt), number=number) / number
    lark_time = 1000 * timeit.timeit(lambda: parser_lark(txt), number=number) / number
    array.append([len(txt), swiftlet_time, lark_time])

# %%
def grid_graph(array: list):
    df = pd.DataFrame(array, columns=['Text Length', 'swiftlet', 'lark'])
    print(df)

    sns.barplot(df.melt(
        id_vars=['Text Length'],
        value_vars=['swiftlet', 'lark'],
        var_name='Package Name',
        value_name='Package Time',
    ),
        x="Text Length",
        y="Package Time",
        hue="Package Name",
    )
grid_graph(array)
# Out:
#    Text Length  swiftlet       lark
# 0           42  0.906884   3.876742
# 1         5969  2.519707   9.466563
# 2        12941  3.986612  15.294750
# 3        20006  6.027964  20.602150
# 4        26966  7.235315  25.623798

# %%
# -------------- Swiftlet ------------------ #
grammar_swiftlet = """
    start: expr
    expr: expr "+" factors -> add
        | expr "-" factors -> sub
        | factors

    factors: factors "*" INT -> mul
        | factors "/" INT -> div
        | INT

    # %import (WS, INT)
    # %ignore WS
    """
swiftlet_parser = swiftlet.Swiftlet(grammar=grammar_swiftlet, algorithm="clr")

# -------------- Lark ------------------ #
grammar = """
    start: expr
    expr: expr "+" factors -> add
        | expr "-" factors -> sub
        | factors

    factors: factors "*" INT -> mul
        | factors "/" INT -> div
        | INT

    # %import common.WS
    # %import common.INT
    # %ignore WS
    """
lark_parser = lark.Lark(grammar, parser="lalr", keep_all_tokens=True)

# %%
arr_parsed = []
for txt in texts[::100]:
    swiftlet_time = 1000 * timeit.timeit(lambda: swiftlet_parser.parse(txt), number=number) / number
    lark_time = 1000 * timeit.timeit(lambda: lark_parser.parse(txt), number=number) / number
    arr_parsed.append([len(txt), swiftlet_time, lark_time])

# %%
grid_graph(arr_parsed)
# Out:
#    Text Length  swiftlet       lark
# 0           42  0.026185   0.070346
# 1         5969  1.460676   5.226540
# 2        12941  2.954228  10.428301
# 3        20006  4.370766  15.610847
# 4        26966  5.828957  20.789283

# %%
cProfile.run('parser_swiftlet(texts[98])')
# Out:
#          5 function calls in 0.006 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003    0.006    0.006 2891851176.py:1(parser_swiftlet)
#         1    0.000    0.000    0.006    0.006 <string>:1(<module>)
#         1    0.000    0.000    0.006    0.006 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.003    0.003    0.003    0.003 {method 'parse' of 'swiftlet._core.Swiftlet' objects}

# %%
cProfile.run('parser_lark(texts[98])')
# Out:
#          106761 function calls (105307 primitive calls) in 0.053 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.053    0.053 595936109.py:1(parser_lark)
#         2    0.000    0.000    0.000    0.000 <frozen _collections_abc>:576(_from_iterable)
#         2    0.000    0.000    0.000    0.000 <frozen _collections_abc>:599(__or__)
#        10    0.000    0.000    0.000    0.000 <frozen _collections_abc>:602(<genexpr>)
#         8    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap_external>:1127(get_data)
#         1    0.000    0.000    0.000    0.000 <frozen importlib.util>:74(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen posixpath>:150(dirname)
#         4    0.000    0.000    0.000    0.000 <frozen posixpath>:41(_get_sep)
#         3    0.000    0.000    0.000    0.000 <frozen posixpath>:71(join)
#         1    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    0.053    0.053 <string>:1(<module>)
#         3    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:163(match)
#         2    0.000    0.000    0.000    0.000 __init__.py:173(search)
#        19    0.000    0.000    0.000    0.000 __init__.py:225(compile)
#        20    0.000    0.000    0.000    0.000 __init__.py:253(escape)
#        25    0.000    0.000    0.000    0.000 __init__.py:272(_compile)
#         6    0.000    0.000    0.000    0.000 _parser.py:113(__init__)
#         8    0.000    0.000    0.000    0.000 _parser.py:164(__len__)
#        14    0.000    0.000    0.000    0.000 _parser.py:168(__getitem__)
#         2    0.000    0.000    0.000    0.000 _parser.py:172(__setitem__)
#         4    0.000    0.000    0.000    0.000 _parser.py:176(append)
#       4/2    0.000    0.000    0.000    0.000 _parser.py:178(getwidth)
#         2    0.000    0.000    0.000    0.000 _parser.py:231(__init__)
#        24    0.000    0.000    0.000    0.000 _parser.py:240(__next)
#        20    0.000    0.000    0.000    0.000 _parser.py:256(match)
#        17    0.000    0.000    0.000    0.000 _parser.py:261(get)
#        10    0.000    0.000    0.000    0.000 _parser.py:293(tell)
#         2    0.000    0.000    0.000    0.000 _parser.py:453(_uniq)
#       4/2    0.000    0.000    0.000    0.000 _parser.py:456(_parse_sub)
#       4/2    0.000    0.000    0.000    0.000 _parser.py:516(_parse)
#         2    0.000    0.000    0.000    0.000 _parser.py:77(__init__)
#         2    0.000    0.000    0.000    0.000 _parser.py:963(fix_flags)
#         2    0.000    0.000    0.000    0.000 _parser.py:979(parse)
#         7    0.000    0.000    0.000    0.000 ast.py:33(parse)
#         7    0.000    0.000    0.000    0.000 ast.py:54(literal_eval)
#         7    0.000    0.000    0.000    0.000 ast.py:84(_convert)
#         1    0.000    0.000    0.000    0.000 common.py:42(__init__)
#         1    0.000    0.000    0.000    0.000 common.py:45(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 common.py:80(__init__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:440(__init__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:443(__enter__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:446(__exit__)
#    641/27    0.001    0.000    0.003    0.000 copy.py:128(deepcopy)
#       125    0.000    0.000    0.000    0.000 copy.py:182(_deepcopy_atomic)
#    185/27    0.000    0.000    0.003    0.000 copy.py:201(_deepcopy_list)
#        25    0.000    0.000    0.000    0.000 copy.py:210(_deepcopy_tuple)
#        25    0.000    0.000    0.000    0.000 copy.py:211(<listcomp>)
#        50    0.000    0.000    0.000    0.000 copy.py:227(_deepcopy_dict)
#       516    0.000    0.000    0.000    0.000 copy.py:243(_keep_alive)
#        32    0.000    0.000    0.001    0.000 copy.py:259(_reconstruct)
#        50    0.000    0.000    0.000    0.000 copy.py:264(<genexpr>)
#         7    0.000    0.000    0.000    0.000 copy.py:66(copy)
#        32    0.000    0.000    0.000    0.000 copyreg.py:104(__newobj__)
#         6    0.000    0.000    0.000    0.000 exceptions.py:19(assert_config)
#        51    0.000    0.000    0.000    0.000 functools.py:35(update_wrapper)
#         9    0.000    0.000    0.000    0.000 grammar.py:109(__init__)
#      2461    0.000    0.000    0.000    0.000 grammar.py:127(__hash__)
#      2309    0.001    0.000    0.001    0.000 grammar.py:130(__eq__)
#        24    0.000    0.000    0.000    0.000 grammar.py:15(__init__)
#       321    0.000    0.000    0.000    0.000 grammar.py:18(__eq__)
#        40    0.000    0.000    0.000    0.000 grammar.py:23(__ne__)
#      1011    0.000    0.000    0.000    0.000 grammar.py:26(__hash__)
#        60    0.000    0.000    0.000    0.000 grammar.py:43(__init__)
#        25    0.000    0.000    0.000    0.000 grammar.py:51(renamed)
#         8    0.000    0.000    0.000    0.000 grammar.py:75(__init__)
#         1    0.000    0.000    0.001    0.001 grammar_analysis.py:141(__init__)
#         1    0.000    0.000    0.000    0.000 grammar_analysis.py:145(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 grammar_analysis.py:149(<lambda>)
#         1    0.000    0.000    0.000    0.000 grammar_analysis.py:160(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 grammar_analysis.py:163(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 grammar_analysis.py:166(<dictcomp>)
#        50    0.000    0.000    0.000    0.000 grammar_analysis.py:17(__init__)
#         8    0.000    0.000    0.000    0.000 grammar_analysis.py:172(<lambda>)
#         1    0.000    0.000    0.000    0.000 grammar_analysis.py:175(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 grammar_analysis.py:180(expand_rule)
#        28    0.000    0.000    0.000    0.000 grammar_analysis.py:187(_expand_rule)
#       123    0.000    0.000    0.000    0.000 grammar_analysis.py:28(next)
#        26    0.000    0.000    0.000    0.000 grammar_analysis.py:32(advance)
#       116    0.000    0.000    0.000    0.000 grammar_analysis.py:36(is_satisfied)
#         6    0.000    0.000    0.000    0.000 grammar_analysis.py:40(__eq__)
#        74    0.000    0.000    0.000    0.000 grammar_analysis.py:45(__hash__)
#        13    0.000    0.000    0.000    0.000 grammar_analysis.py:60(__init__)
#        83    0.000    0.000    0.000    0.000 grammar_analysis.py:70(update_set)
#         1    0.000    0.000    0.000    0.000 grammar_analysis.py:78(calculate_sets)
#         1    0.000    0.000    0.000    0.000 grammar_analysis.py:82(<setcomp>)
#         2    0.000    0.000    0.000    0.000 lalr_analysis.py:106(digraph)
#      10/8    0.000    0.000    0.000    0.000 lalr_analysis.py:123(traverse)
#         1    0.000    0.000    0.001    0.001 lalr_analysis.py:157(__init__)
#         1    0.000    0.000    0.000    0.000 lalr_analysis.py:166(compute_lr0_states)
#        31    0.000    0.000    0.000    0.000 lalr_analysis.py:171(step)
#        34    0.000    0.000    0.000    0.000 lalr_analysis.py:172(<lambda>)
#        26    0.000    0.000    0.000    0.000 lalr_analysis.py:174(<lambda>)
#        18    0.000    0.000    0.000    0.000 lalr_analysis.py:176(<setcomp>)
#         1    0.000    0.000    0.000    0.000 lalr_analysis.py:194(compute_reads_relations)
#         1    0.000    0.000    0.000    0.000 lalr_analysis.py:229(compute_includes_lookback)
#         1    0.000    0.000    0.000    0.000 lalr_analysis.py:258(compute_lookaheads)
#         1    0.000    0.000    0.000    0.000 lalr_analysis.py:267(compute_lalr1_states)
#        13    0.000    0.000    0.000    0.000 lalr_analysis.py:271(<dictcomp>)
#        13    0.000    0.000    0.000    0.000 lalr_analysis.py:299(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 lalr_analysis.py:310(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 lalr_analysis.py:321(<dictcomp>)
#         1    0.000    0.000    0.001    0.001 lalr_analysis.py:329(compute_lalr)
#         2    0.000    0.000    0.000    0.000 lalr_analysis.py:39(__init__)
#         1    0.000    0.000    0.000    0.000 lalr_analysis.py:81(from_ParseTable)
#         1    0.000    0.000    0.000    0.000 lalr_analysis.py:84(<dictcomp>)
#        13    0.000    0.000    0.000    0.000 lalr_analysis.py:88(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 lalr_analysis.py:93(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 lalr_analysis.py:94(<dictcomp>)
#         1    0.000    0.000    0.002    0.002 lalr_parser.py:18(__init__)
#         3    0.000    0.000    0.034    0.011 lalr_parser.py:40(parse)
#         1    0.000    0.000    0.000    0.000 lalr_parser.py:78(__init__)
#         3    0.000    0.000    0.034    0.011 lalr_parser.py:83(parse)
#         3    0.001    0.000    0.034    0.011 lalr_parser.py:91(parse_from_state)
#         3    0.000    0.000    0.000    0.000 lalr_parser_state.py:22(__init__)
#         3    0.000    0.000    0.000    0.000 lalr_parser_state.py:40(__init__)
#      1982    0.000    0.000    0.000    0.000 lalr_parser_state.py:46(position)
#      2222    0.008    0.000    0.012    0.000 lalr_parser_state.py:67(feed_token)
#         1    0.000    0.000    0.000    0.000 lark.py:194(__init__)
#        48    0.000    0.000    0.000    0.000 lark.py:226(__getattr__)
#         2    0.000    0.000    0.000    0.000 lark.py:232(__setattr__)
#         1    0.000    0.000    0.027    0.027 lark.py:278(__init__)
#         1    0.000    0.000    0.000    0.000 lark.py:430(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 lark.py:482(_prepare_callbacks)
#         1    0.000    0.000    0.003    0.003 lark.py:496(_build_parser)
#         1    0.000    0.000    0.026    0.026 lark.py:654(parse)
#        20    0.000    0.000    0.000    0.000 lexer.py:102(_get_width)
#         9    0.000    0.000    0.000    0.000 lexer.py:107(min_width)
#        11    0.000    0.000    0.000    0.000 lexer.py:111(max_width)
#         6    0.000    0.000    0.000    0.000 lexer.py:125(__init__)
#      2268    0.001    0.000    0.003    0.000 lexer.py:202(__new__)
#      2268    0.001    0.000    0.002    0.000 lexer.py:213(_future_new)
#         3    0.000    0.000    0.000    0.000 lexer.py:252(new_borrow_pos)
#        46    0.000    0.000    0.000    0.000 lexer.py:262(__deepcopy__)
#      1697    0.001    0.000    0.001    0.000 lexer.py:265(__eq__)
#         3    0.000    0.000    0.000    0.000 lexer.py:279(__init__)
#      4294    0.002    0.000    0.003    0.000 lexer.py:292(feed)
#         4    0.000    0.000    0.000    0.000 lexer.py:329(_get_match)
#         4    0.000    0.000    0.000    0.000 lexer.py:334(_create_unless)
#        11    0.000    0.000    0.000    0.000 lexer.py:335(<lambda>)
#         4    0.000    0.000    0.000    0.000 lexer.py:352(<listcomp>)
#         4    0.000    0.000    0.000    0.000 lexer.py:357(__init__)
#         4    0.000    0.000    0.000    0.000 lexer.py:363(<setcomp>)
#         4    0.000    0.000    0.000    0.000 lexer.py:367(_build_mres)
#        15    0.000    0.000    0.000    0.000 lexer.py:373(<genexpr>)
#      4294    0.003    0.000    0.005    0.000 lexer.py:385(match)
#        21    0.000    0.000    0.000    0.000 lexer.py:399(_regexp_has_newline)
#         8    0.000    0.000    0.000    0.000 lexer.py:41(__init__)
#         3    0.000    0.000    0.000    0.000 lexer.py:421(__init__)
#         3    0.000    0.000    0.000    0.000 lexer.py:452(__init__)
#         3    0.000    0.000    0.000    0.000 lexer.py:456(from_text)
#         3    0.000    0.000    0.000    0.000 lexer.py:465(lex)
#        18    0.000    0.000    0.000    0.000 lexer.py:50(__hash__)
#       240    0.000    0.000    0.003    0.000 lexer.py:536(lex)
#         7    0.000    0.000    0.000    0.000 lexer.py:550(__init__)
#        28    0.000    0.000    0.000    0.000 lexer.py:552(<genexpr>)
#         6    0.000    0.000    0.000    0.000 lexer.py:571(<setcomp>)
#        14    0.000    0.000    0.000    0.000 lexer.py:580(<genexpr>)
#        21    0.000    0.000    0.000    0.000 lexer.py:583(<lambda>)
#         4    0.000    0.000    0.000    0.000 lexer.py:592(_build_scanner)
#      4294    0.001    0.000    0.001    0.000 lexer.py:605(scanner)
#      4294    0.002    0.000    0.008    0.000 lexer.py:611(match)
#      2222    0.006    0.000    0.019    0.000 lexer.py:614(next_token)
#         1    0.000    0.000    0.001    0.001 lexer.py:655(__init__)
#         6    0.000    0.000    0.000    0.000 lexer.py:675(<listcomp>)
#      1982    0.001    0.000    0.018    0.000 lexer.py:685(lex)
#        55    0.000    0.000    0.000    0.000 lexer.py:70(_get_flags)
#        20    0.000    0.000    0.000    0.000 lexer.py:81(to_regexp)
#         6    0.000    0.000    0.000    0.000 lexer.py:84(min_width)
#        10    0.000    0.000    0.000    0.000 lexer.py:88(max_width)
#        35    0.000    0.000    0.000    0.000 lexer.py:98(to_regexp)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:1030(_get_mangle)
#        54    0.000    0.000    0.000    0.000 load_grammar.py:1031(mangle)
#        30    0.000    0.000    0.004    0.000 load_grammar.py:1044(_mangle_definition_tree)
#         3    0.000    0.000    0.000    0.000 load_grammar.py:1055(_make_rule_tuple)
#         3    0.000    0.000    0.000    0.000 load_grammar.py:1073(<listcomp>)
#        30    0.000    0.000    0.000    0.000 load_grammar.py:1080(__init__)
#         2    0.000    0.000    0.000    0.000 load_grammar.py:1095(__init__)
#        30    0.000    0.000    0.000    0.000 load_grammar.py:1112(_check_options)
#        30    0.000    0.000    0.000    0.000 load_grammar.py:1128(_define)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:1160(_ignore)
#         2    0.000    0.000    0.000    0.000 load_grammar.py:1181(_unpack_import)
#        30    0.000    0.000    0.004    0.000 load_grammar.py:1220(_unpack_definition)
#        27    0.000    0.000    0.000    0.000 load_grammar.py:1233(<genexpr>)
#       2/1    0.000    0.000    0.022    0.022 load_grammar.py:1240(load_grammar)
#         2    0.000    0.000    0.000    0.000 load_grammar.py:1286(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:1293(_remove_unused)
#         2    0.000    0.000    0.000    0.000 load_grammar.py:1294(rule_dependencies)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:1304(<dictcomp>)
#         1    0.000    0.000    0.017    0.017 load_grammar.py:1307(do_import)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:1343(validate)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:1375(build)
#         1    0.000    0.000    0.022    0.022 load_grammar.py:1414(load_grammar)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:1420(sha256_digest)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:228(__init__)
#        10    0.000    0.000    0.000    0.000 load_grammar.py:384(_flatten)
#         7    0.000    0.000    0.000    0.000 load_grammar.py:389(expansion)
#         4    0.000    0.000    0.000    0.000 load_grammar.py:411(alias)
#         3    0.000    0.000    0.000    0.000 load_grammar.py:420(expansions)
#         3    0.000    0.000    0.000    0.000 load_grammar.py:428(expansions)
#         7    0.000    0.000    0.000    0.000 load_grammar.py:431(expansion)
#         4    0.000    0.000    0.000    0.000 load_grammar.py:434(alias)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:443(__init__)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:445(<setcomp>)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:446(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 load_grammar.py:450(pattern)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:498(__init__)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:516(__init__)
#         5    0.000    0.000    0.000    0.000 load_grammar.py:536(_rfind)
#        15    0.000    0.000    0.000    0.000 load_grammar.py:537(<genexpr>)
#         7    0.000    0.000    0.000    0.000 load_grammar.py:540(eval_escaping)
#         5    0.000    0.000    0.000    0.000 load_grammar.py:566(_literal_to_pattern)
#         5    0.000    0.000    0.000    0.000 load_grammar.py:572(<genexpr>)
#         5    0.000    0.000    0.000    0.000 load_grammar.py:601(literal)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:604(range)
#         2    0.000    0.000    0.000    0.000 load_grammar.py:617(pattern)
#         3    0.000    0.000    0.000    0.000 load_grammar.py:621(expansion)
#         3    0.000    0.000    0.000    0.000 load_grammar.py:631(expansions)
#         2    0.000    0.000    0.000    0.000 load_grammar.py:642(expr)
#         3    0.000    0.000    0.000    0.000 load_grammar.py:663(value)
#        15    0.000    0.000    0.000    0.000 load_grammar.py:668(value)
#         5    0.000    0.000    0.000    0.000 load_grammar.py:674(nr_deepcopy_tree)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:685(__init__)
#         1    0.000    0.000    0.002    0.002 load_grammar.py:692(compile)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:695(<listcomp>)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:696(<listcomp>)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:712(<listcomp>)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:745(<setcomp>)
#        22    0.000    0.000    0.000    0.000 load_grammar.py:761(<genexpr>)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:795(<setcomp>)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:799(<setcomp>)
#         7    0.000    0.000    0.000    0.000 load_grammar.py:800(<lambda>)
#         1    0.000    0.000    0.000    0.000 load_grammar.py:808(<setcomp>)
#         6    0.000    0.000    0.000    0.000 load_grammar.py:811(<lambda>)
#         1    0.000    0.000    0.002    0.002 load_grammar.py:842(__call__)
#         2    0.000    0.000    0.003    0.001 load_grammar.py:870(resolve_term_references)
#        35    0.000    0.000    0.000    0.000 load_grammar.py:898(<listcomp>)
#        29    0.000    0.000    0.000    0.000 load_grammar.py:910(terminal)
#        12    0.000    0.000    0.000    0.000 load_grammar.py:913(nonterminal)
#         5    0.000    0.000    0.000    0.000 load_grammar.py:917(_find_used_symbols)
#         5    0.000    0.000    0.000    0.000 load_grammar.py:919(<setcomp>)
#        22    0.000    0.000    0.000    0.000 load_grammar.py:920(<lambda>)
#         2    0.000    0.000    0.000    0.000 load_grammar.py:923(_get_parser)
#         2    0.000    0.000    0.013    0.006 load_grammar.py:966(_parse_grammar)
#       288    0.000    0.000    0.001    0.000 parse_tree_builder.py:145(__call__)
#        15    0.000    0.000    0.000    0.000 parse_tree_builder.py:158(_should_expand)
#         7    0.000    0.000    0.000    0.000 parse_tree_builder.py:162(maybe_create_child_filter)
#        22    0.000    0.000    0.000    0.000 parse_tree_builder.py:182(<genexpr>)
#       223    0.000    0.000    0.000    0.000 parse_tree_builder.py:20(__call__)
#         1    0.000    0.000    0.000    0.000 parse_tree_builder.py:332(__init__)
#         8    0.000    0.000    0.000    0.000 parse_tree_builder.py:340(_init_builders)
#         1    0.000    0.000    0.000    0.000 parse_tree_builder.py:358(create_callback)
#         1    0.000    0.000    0.000    0.000 parse_tree_builder.py:83(make_propagate_positions)
#         3    0.000    0.000    0.000    0.000 parser_frontends.py:103(_verify_start)
#         3    0.000    0.000    0.000    0.000 parser_frontends.py:113(_make_lexer_thread)
#         3    0.000    0.000    0.034    0.011 parser_frontends.py:123(parse)
#         1    0.000    0.000    0.000    0.000 parser_frontends.py:143(_validate_frontend_args)
#         1    0.000    0.000    0.000    0.000 parser_frontends.py:154(_get_lexer_callbacks)
#         1    0.000    0.000    0.001    0.001 parser_frontends.py:177(create_contextual_lexer)
#         1    0.000    0.000    0.000    0.000 parser_frontends.py:180(<dictcomp>)
#         1    0.000    0.000    0.002    0.002 parser_frontends.py:184(create_lalr_parser)
#         1    0.000    0.000    0.003    0.003 parser_frontends.py:273(_construct_parsing_frontend)
#         1    0.000    0.000    0.003    0.003 parser_frontends.py:65(__init__)
#         1    0.000    0.000    0.002    0.002 pkgutil.py:600(get_data)
#      11/7    0.000    0.000    0.000    0.000 tree.py:134(__hash__)
#       152    0.002    0.000    0.004    0.000 tree.py:137(iter_subtrees)
#      2113    0.001    0.000    0.002    0.000 tree.py:146(<listcomp>)
#        68    0.000    0.000    0.001    0.000 tree.py:168(find_pred)
#        68    0.000    0.000    0.002    0.000 tree.py:172(find_data)
#       779    0.000    0.000    0.000    0.000 tree.py:174(<lambda>)
#        10    0.000    0.000    0.000    0.000 tree.py:188(expand_kids_by_data)
#     62/21    0.000    0.000    0.000    0.000 tree.py:199(scan_values)
#    185/27    0.000    0.000    0.003    0.000 tree.py:215(__deepcopy__)
#       312    0.000    0.000    0.000    0.000 tree.py:30(__init__)
#      2676    0.001    0.000    0.001    0.000 tree.py:59(__init__)
#       464    0.000    0.000    0.000    0.000 tree.py:64(meta)
#        12    0.000    0.000    0.000    0.000 typing.py:2287(cast)
#         5    0.000    0.000    0.000    0.000 typing.py:373(inner)
#         2    0.000    0.000    0.000    0.000 utils.py:134(get_regexp_width)
#         2    0.000    0.000    0.000    0.000 utils.py:146(<listcomp>)
#         3    0.000    0.000    0.000    0.000 utils.py:194(__post_init__)
#         3    0.000    0.000    0.000    0.000 utils.py:208(cast_from)
#        19    0.000    0.000    0.000    0.000 utils.py:25(classify)
#        15    0.000    0.000    0.000    0.000 utils.py:324(classify_bool)
#        15    0.000    0.000    0.000    0.000 utils.py:326(<listcomp>)
#     31/27    0.000    0.000    0.001    0.000 utils.py:330(bfs)
#         6    0.000    0.000    0.000    0.000 utils.py:394(__init__)
#        22    0.000    0.000    0.000    0.000 utils.py:400(add)
#         5    0.000    0.000    0.000    0.000 utils.py:403(__iter__)
#        12    0.000    0.000    0.000    0.000 visitors.py:108(__init__)
#       506    0.001    0.000    0.002    0.000 visitors.py:111(_call_userfunc)
#       136    0.000    0.000    0.000    0.000 visitors.py:130(_call_userfunc_token)
# 1122/1078    0.001    0.000    0.003    0.000 visitors.py:143(_transform_children)
#      14/3    0.000    0.000    0.000    0.000 visitors.py:155(_transform_tree)
#         3    0.000    0.000    0.000    0.000 visitors.py:159(transform)
#         2    0.000    0.000    0.000    0.000 visitors.py:167(__mul__)
#       413    0.000    0.000    0.000    0.000 visitors.py:175(__default__)
#       136    0.000    0.000    0.000    0.000 visitors.py:182(__default_token__)
#         4    0.000    0.000    0.000    0.000 visitors.py:259(__init__)
#         5    0.000    0.000    0.001    0.000 visitors.py:262(transform)
#         2    0.000    0.000    0.000    0.000 visitors.py:267(__mul__)
#       433    0.000    0.000    0.002    0.000 visitors.py:279(_transform_tree)
#        19    0.000    0.000    0.005    0.000 visitors.py:282(transform)
#         7    0.000    0.000    0.000    0.000 visitors.py:297(transform)
#        14    0.000    0.000    0.000    0.000 visitors.py:346(_call_userfunc)
#         3    0.000    0.000    0.000    0.000 visitors.py:366(visit)
#        51    0.000    0.000    0.000    0.000 visitors.py:474(__init__)
#        51    0.000    0.000    0.000    0.000 visitors.py:481(__call__)
#        51    0.000    0.000    0.000    0.000 visitors.py:484(__get__)
#        51    0.000    0.000    0.000    0.000 visitors.py:503(_vargs_inline)
#      2301    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1039e4cd0}
#         8    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_sha256}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        14    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         1    0.000    0.000    0.053    0.053 {built-in method builtins.exec}
# 1415/1058    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#        34    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
# 1123/1073    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#      6125    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#     11797    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
#       265    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 7402/7398    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#       280    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#        10    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         1    0.002    0.002    0.002    0.002 {built-in method io.open_code}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        32    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#       120    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        18    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#     10211    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      2075    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#      1356    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#      4294    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'issuperset' of 'set' objects}
#       168    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#      4298    0.002    0.000    0.002    0.000 {method 'match' of 're.Pattern' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        97    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        25    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#        18    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        53    0.000    0.000    0.000    0.000 {method 'rindex' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         7    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#        75    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'translate' of 'str' objects}
#        86    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#       160    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}

# %%
len(texts)
# Out:
# 499

# %%
ast_lark = parser_lark("4 + 3 * 6 - 8 / 2")
print(ast_lark.pretty())
# Out:
# start
#   sub
#     add
#       expr
#         factors	4
#       +
#       mul
#         factors	3
#         *
#         6
#     -
#     div
#       factors	8
#       /
#       2

# %%
ast_rust = parser_swiftlet("4 + 3 * 6 - 8 / 2")
swiftlet.pretty_print(ast_rust)
# Out:
#  start
#    sub
#      add
#        expr
#          factors 	 4
#        +
#        mul
#          factors 	 3
#          *
#          6
#      -
#      div
#        factors 	 8
#        /
#        2
